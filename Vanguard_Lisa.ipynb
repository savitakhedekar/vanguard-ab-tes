# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)

pd.set_option('display.max_colwidth', 1)
#to show all values in row

# %%
client_profiles = pd.read_csv("df_final_demo.txt")

# %%
client_profiles
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0      836976     6.0             73.0              60.5      U     2.0
# 1      2304905    7.0             94.0              58.0      U     2.0
# 2      1439522    5.0             64.0              32.0      U     2.0
# 3      1562045    16.0            198.0             49.0      M     2.0
# 4      5126305    12.0            145.0             33.0      F     2.0
# ...        ...     ...              ...              ...     ..     ...
# 70604  7993686    4.0             56.0              38.5      U     3.0
# 70605  8981690    12.0            148.0             31.0      M     2.0
# 70606  333913     16.0            198.0             61.5      F     2.0
# 70607  1573142    21.0            255.0             68.0      M     3.0
# 70608  5602139    21.0            254.0             59.5      F     3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 0      45105.30    6.0           9.0
# 1      110860.30   6.0           9.0
# 2      52467.79    6.0           9.0
# 3      67454.65    3.0           6.0
# 4      103671.75   0.0           3.0
# ...          ...   ...           ...
# 70604  1411062.68  5.0           5.0
# 70605  101867.07   6.0           6.0
# 70606  40745.00    3.0           3.0
# 70607  475114.69   4.0           4.0
# 70608  157498.73   7.0           7.0
#
# [70609 rows x 9 columns]

# %%
digital_footprints_pt_1 = pd.read_csv("df_final_web_data_pt_1.txt")

# %%
digital_footprints_pt_1
# Out:
#         client_id             visitor_id                      visit_id  \
# 0       9988021    580560515_7732621733   781255054_21935453173_531117
# 1       9988021    580560515_7732621733   781255054_21935453173_531117
# 2       9988021    580560515_7732621733   781255054_21935453173_531117
# 3       9988021    580560515_7732621733   781255054_21935453173_531117
# 4       9988021    580560515_7732621733   781255054_21935453173_531117
# ...         ...                     ...                            ...
# 343136  2443347    465784886_73090545671  136329900_10529659391_316129
# 343137  2443347    465784886_73090545671  136329900_10529659391_316129
# 343138  2443347    465784886_73090545671  136329900_10529659391_316129
# 343139  2443347    465784886_73090545671  136329900_10529659391_316129
# 343140  2443347    465784886_73090545671  136329900_10529659391_316129
#
#        process_step            date_time
# 0       step_3       2017-04-17 15:27:07
# 1       step_2       2017-04-17 15:26:51
# 2       step_3       2017-04-17 15:19:22
# 3       step_2       2017-04-17 15:19:13
# 4       step_3       2017-04-17 15:18:04
# ...        ...                       ...
# 343136  confirm      2017-03-31 15:15:46
# 343137  step_3       2017-03-31 15:14:53
# 343138  step_2       2017-03-31 15:12:08
# 343139  step_1       2017-03-31 15:11:37
# 343140  start        2017-03-31 15:10:47
#
# [343141 rows x 5 columns]

# %%
digital_footprints_pt_2 = pd.read_csv("df_final_web_data_pt_2.txt")

# %%
digital_footprints_pt_2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0       763412     601952081_10457207388  397475557_40440946728_419634
# 1       6019349    442094451_91531546617  154620534_35331068705_522317
# 2       6019349    442094451_91531546617  154620534_35331068705_522317
# 3       6019349    442094451_91531546617  154620534_35331068705_522317
# 4       6019349    442094451_91531546617  154620534_35331068705_522317
# ...         ...                      ...                           ...
# 412259  9668240    388766751_9038881013   922267647_3096648104_968866
# 412260  9668240    388766751_9038881013   922267647_3096648104_968866
# 412261  9668240    388766751_9038881013   922267647_3096648104_968866
# 412262  9668240    388766751_9038881013   922267647_3096648104_968866
# 412263  674799     947159805_81558194550  86152093_47511127657_716022
#
#        process_step            date_time
# 0       confirm      2017-06-06 08:56:00
# 1       confirm      2017-06-01 11:59:27
# 2       step_3       2017-06-01 11:58:48
# 3       step_2       2017-06-01 11:58:08
# 4       step_1       2017-06-01 11:57:58
# ...        ...                       ...
# 412259  start        2017-05-24 18:46:10
# 412260  start        2017-05-24 18:45:29
# 412261  step_1       2017-05-24 18:44:51
# 412262  start        2017-05-24 18:44:34
# 412263  start        2017-06-03 12:17:09
#
# [412264 rows x 5 columns]

# %%
experiment_roster = pd.read_csv("df_final_experiment_clients.txt")

# %%
experiment_roster
# Out:
#        client_id Variation
# 0      9988021    Test
# 1      8320017    Test
# 2      4033851    Control
# 3      1982004    Test
# 4      9294070    Control
# ...        ...        ...
# 70604  2443347    NaN
# 70605  8788427    NaN
# 70606  266828     NaN
# 70607  1266421    NaN
# 70608  9895983    NaN
#
# [70609 rows x 2 columns]

# %% [markdown]
# # Merging and Cleaning Data: client_profiles¶

# %%
#Checking unique values in client_profiles

client_profiles.nunique()
# Out:
# client_id           70609
# clnt_tenure_yr      54
# clnt_tenure_mnth    482
# clnt_age            165
# gendr               4
# num_accts           8
# bal                 70328
# calls_6_mnth        8
# logons_6_mnth       9
# dtype: int64

# %%
#Checking unique values in experiment_roster

experiment_roster.nunique()
# Out:
# client_id    70609
# Variation    2
# dtype: int64

# %%
#Merging client_profiles and experiment_roster

client_profiles = pd.merge(client_profiles, experiment_roster, on='client_id', how='inner')

# %%
client_profiles
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0      836976     6.0             73.0              60.5      U     2.0
# 1      2304905    7.0             94.0              58.0      U     2.0
# 2      1439522    5.0             64.0              32.0      U     2.0
# 3      1562045    16.0            198.0             49.0      M     2.0
# 4      5126305    12.0            145.0             33.0      F     2.0
# ...        ...     ...              ...              ...     ..     ...
# 70604  7993686    4.0             56.0              38.5      U     3.0
# 70605  8981690    12.0            148.0             31.0      M     2.0
# 70606  333913     16.0            198.0             61.5      F     2.0
# 70607  1573142    21.0            255.0             68.0      M     3.0
# 70608  5602139    21.0            254.0             59.5      F     3.0
#
#               bal  calls_6_mnth  logons_6_mnth Variation
# 0      45105.30    6.0           9.0            Test
# 1      110860.30   6.0           9.0            Control
# 2      52467.79    6.0           9.0            Test
# 3      67454.65    3.0           6.0            Test
# 4      103671.75   0.0           3.0            Control
# ...          ...   ...           ...                ...
# 70604  1411062.68  5.0           5.0            NaN
# 70605  101867.07   6.0           6.0            NaN
# 70606  40745.00    3.0           3.0            NaN
# 70607  475114.69   4.0           4.0            NaN
# 70608  157498.73   7.0           7.0            NaN
#
# [70609 rows x 10 columns]

# %%
#Checking Null-values 

client_profiles.isnull().sum()
# Out:
# client_id           0
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# clnt_age            15
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# Variation           20109
# dtype: int64

# %%
#Checking rows witn Null-values in column 'clnt_age'

client_profiles.loc[client_profiles["clnt_age"].isna()]
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 4164   7402828   NaN             NaN               NaN        NaN  NaN
# 8316   355337    NaN             NaN               NaN        NaN  NaN
# 8677   8412164   NaN             NaN               NaN        NaN  NaN
# 9583   4666211    8.0             106.0            NaN        F     2.0
# 13444  2222915   NaN             NaN               NaN        NaN  NaN
# 18066  4876926   NaN             NaN               NaN        NaN  NaN
# 25961  5277910   NaN             NaN               NaN        NaN  NaN
# 28432  7616759   NaN             NaN               NaN        NaN  NaN
# 35323  8191345   NaN             NaN               NaN        NaN  NaN
# 43518  1227228   NaN             NaN               NaN        NaN  NaN
# 46076  8611797   NaN             NaN               NaN        NaN  NaN
# 47189  5144725   NaN             NaN               NaN        NaN  NaN
# 49846  1037867   NaN             NaN               NaN        NaN  NaN
# 63701  1618749   NaN             NaN               NaN        NaN  NaN
# 66219  6021001   NaN             NaN               NaN        NaN  NaN
#
#             bal  calls_6_mnth  logons_6_mnth Variation
# 4164  NaN       NaN           NaN             Control
# 8316  NaN       NaN           NaN             Control
# 8677  NaN       NaN           NaN             Test
# 9583   42550.55  4.0           7.0            Control
# 13444 NaN       NaN           NaN             Test
# 18066 NaN       NaN           NaN             Test
# 25961 NaN       NaN           NaN             Test
# 28432 NaN       NaN           NaN             Control
# 35323 NaN       NaN           NaN             Control
# 43518 NaN       NaN           NaN             Test
# 46076 NaN       NaN           NaN             Control
# 47189 NaN       NaN           NaN             Test
# 49846 NaN       NaN           NaN             Test
# 63701 NaN       NaN           NaN             NaN
# 66219 NaN       NaN           NaN             NaN

# %%
#Removing rows with Null-values in column "clnt_age" 

client_profiles.dropna(subset = 'gendr', inplace = True)

# %%
#Checking Null-values 

client_profiles.isnull().sum()
# Out:
# client_id           0
# clnt_tenure_yr      0
# clnt_tenure_mnth    0
# clnt_age            1
# gendr               0
# num_accts           0
# bal                 0
# calls_6_mnth        0
# logons_6_mnth       0
# Variation           20107
# dtype: int64

# %%
# Replace missing values in 'clnt_age' with the mode

mode_clnt_age = client_profiles['clnt_age'].mode()[0]
client_profiles['clnt_age'].fillna(mode_clnt_age, inplace=True)

# %%
#Checking Null-values 

client_profiles.isnull().sum()
# Out:
# client_id           0
# clnt_tenure_yr      0
# clnt_tenure_mnth    0
# clnt_age            0
# gendr               0
# num_accts           0
# bal                 0
# calls_6_mnth        0
# logons_6_mnth       0
# Variation           20107
# dtype: int64

# %%
#Checking duplicates

client_profiles.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Merging and Cleaning Data: digital_footprints

# %%
#Merging 2 dataframes

digital_footprints = pd.concat([digital_footprints_pt_1, digital_footprints_pt_2], axis=0)

# %%
digital_footprints
# Out:
#         client_id             visitor_id                      visit_id  \
# 0       9988021    580560515_7732621733   781255054_21935453173_531117
# 1       9988021    580560515_7732621733   781255054_21935453173_531117
# 2       9988021    580560515_7732621733   781255054_21935453173_531117
# 3       9988021    580560515_7732621733   781255054_21935453173_531117
# 4       9988021    580560515_7732621733   781255054_21935453173_531117
# ...         ...                     ...                            ...
# 412259  9668240    388766751_9038881013   922267647_3096648104_968866
# 412260  9668240    388766751_9038881013   922267647_3096648104_968866
# 412261  9668240    388766751_9038881013   922267647_3096648104_968866
# 412262  9668240    388766751_9038881013   922267647_3096648104_968866
# 412263  674799     947159805_81558194550  86152093_47511127657_716022
#
#        process_step            date_time
# 0       step_3       2017-04-17 15:27:07
# 1       step_2       2017-04-17 15:26:51
# 2       step_3       2017-04-17 15:19:22
# 3       step_2       2017-04-17 15:19:13
# 4       step_3       2017-04-17 15:18:04
# ...        ...                       ...
# 412259  start        2017-05-24 18:46:10
# 412260  start        2017-05-24 18:45:29
# 412261  step_1       2017-05-24 18:44:51
# 412262  start        2017-05-24 18:44:34
# 412263  start        2017-06-03 12:17:09
#
# [755405 rows x 5 columns]

# %%
#Checking Null values "digital_footprints"

digital_footprints.isna().sum()
# Out:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64

# %%
#Checking duplicates "digital_footprints"

digital_footprints.duplicated().sum()
# Out:
# 10764

# %%
#Duplicates in "digital_footprints"

digital_footprints.loc[digital_footprints.duplicated()]
# Out:
#         client_id             visitor_id                      visit_id  \
# 365     9358626    148475529_63668223960  223297395_36250329195_832161
# 368     5376894    622509328_44408201172  688984457_43441834354_912755
# 383     438567     923318467_50708963627  330543236_29863358529_771432
# 785     1423857    716830992_81930238382  568819166_80596727019_75889
# 1816    372523     730241475_25771921122  25331354_74479847014_854987
# ...        ...                       ...                          ...
# 412120  1672289    658797407_91003097342  430110748_90347503221_597628
# 412163  4408245    14058946_73585431797   994148957_84373994761_991865
# 412165  4408245    14058946_73585431797   994148957_84373994761_991865
# 412167  4408245    14058946_73585431797   994148957_84373994761_991865
# 412217  3897324    80177429_24869309091   149796456_64325617570_112561
#
#        process_step            date_time
# 365     start        2017-04-28 12:27:28
# 368     start        2017-04-28 14:20:01
# 383     start        2017-04-28 02:52:29
# 785     confirm      2017-04-10 22:44:58
# 1816    start        2017-04-27 10:51:26
# ...       ...                        ...
# 412120  start        2017-05-01 19:28:53
# 412163  start        2017-06-06 09:17:23
# 412165  start        2017-06-06 09:09:44
# 412167  start        2017-06-06 08:51:16
# 412217  start        2017-05-04 08:21:30
#
# [10764 rows x 5 columns]

# %%
#Duplicates "client_id" == 9358626 in "digital_footprints" 

digital_footprints.loc[digital_footprints['client_id'] == 9358626]

#Before deleting duplicates
# Out:
#      client_id             visitor_id                      visit_id  \
# 360  9358626    148475529_63668223960  223297395_36250329195_832161
# 361  9358626    148475529_63668223960  223297395_36250329195_832161
# 362  9358626    148475529_63668223960  223297395_36250329195_832161
# 363  9358626    148475529_63668223960  223297395_36250329195_832161
# 364  9358626    148475529_63668223960  223297395_36250329195_832161
# 365  9358626    148475529_63668223960  223297395_36250329195_832161
#
#     process_step            date_time
# 360  confirm      2017-04-28 12:29:45
# 361  step_3       2017-04-28 12:28:54
# 362  step_2       2017-04-28 12:27:39
# 363  step_1       2017-04-28 12:27:33
# 364  start        2017-04-28 12:27:28
# 365  start        2017-04-28 12:27:28

# %%
#Duplicates "client_id" == 9358626 in "digital_footprints" 

digital_footprints.loc[digital_footprints['client_id'] == 9358626]

#After deleting duplicates
# Out:
#      client_id             visitor_id                      visit_id  \
# 360  9358626    148475529_63668223960  223297395_36250329195_832161
# 361  9358626    148475529_63668223960  223297395_36250329195_832161
# 362  9358626    148475529_63668223960  223297395_36250329195_832161
# 363  9358626    148475529_63668223960  223297395_36250329195_832161
# 364  9358626    148475529_63668223960  223297395_36250329195_832161
# 365  9358626    148475529_63668223960  223297395_36250329195_832161
#
#     process_step            date_time
# 360  confirm      2017-04-28 12:29:45
# 361  step_3       2017-04-28 12:28:54
# 362  step_2       2017-04-28 12:27:39
# 363  step_1       2017-04-28 12:27:33
# 364  start        2017-04-28 12:27:28
# 365  start        2017-04-28 12:27:28

# %%
#Duplicates "client_id" == 9358626 in "digital_footprints" 

digital_footprints.loc[digital_footprints['client_id'] == 1423857]

#Before deleting duplicates
# Out:
#      client_id             visitor_id                      visit_id  \
# 783  1423857    716830992_81930238382  568819166_80596727019_75889
# 784  1423857    716830992_81930238382  568819166_80596727019_75889
# 785  1423857    716830992_81930238382  568819166_80596727019_75889
# 786  1423857    716830992_81930238382  568819166_80596727019_75889
# 787  1423857    716830992_81930238382  568819166_80596727019_75889
# 788  1423857    716830992_81930238382  568819166_80596727019_75889
# 789  1423857    716830992_81930238382  568819166_80596727019_75889
# 790  1423857    716830992_81930238382  568819166_80596727019_75889
# 791  1423857    716830992_81930238382  568819166_80596727019_75889
# 792  1423857    716830992_81930238382  568819166_80596727019_75889
# 860  1423857    868335321_44888951752  393134357_20729844422_611159
# 861  1423857    868335321_44888951752  393134357_20729844422_611159
# 862  1423857    868335321_44888951752  393134357_20729844422_611159
#
#     process_step            date_time
# 783  confirm      2017-04-10 22:44:59
# 784  confirm      2017-04-10 22:44:58
# 785  confirm      2017-04-10 22:44:58
# 786  confirm      2017-04-10 22:44:12
# 787  step_3       2017-04-10 22:43:00
# 788  step_2       2017-04-10 22:42:51
# 789  step_3       2017-04-10 22:42:08
# 790  step_2       2017-04-10 22:40:45
# 791  step_1       2017-04-10 22:40:29
# 792  start        2017-04-10 22:40:02
# 860  step_1       2017-04-13 23:01:11
# 861  start        2017-04-13 23:01:09
# 862  start        2017-04-13 22:54:43

# %%
#Duplicates "client_id" == 9358626 in "digital_footprints" 

digital_footprints.loc[digital_footprints['client_id'] == 1423857]

#After deleting duplicates
# Out:
#      client_id             visitor_id                      visit_id  \
# 783  1423857    716830992_81930238382  568819166_80596727019_75889
# 784  1423857    716830992_81930238382  568819166_80596727019_75889
# 785  1423857    716830992_81930238382  568819166_80596727019_75889
# 786  1423857    716830992_81930238382  568819166_80596727019_75889
# 787  1423857    716830992_81930238382  568819166_80596727019_75889
# 788  1423857    716830992_81930238382  568819166_80596727019_75889
# 789  1423857    716830992_81930238382  568819166_80596727019_75889
# 790  1423857    716830992_81930238382  568819166_80596727019_75889
# 791  1423857    716830992_81930238382  568819166_80596727019_75889
# 792  1423857    716830992_81930238382  568819166_80596727019_75889
# 860  1423857    868335321_44888951752  393134357_20729844422_611159
# 861  1423857    868335321_44888951752  393134357_20729844422_611159
# 862  1423857    868335321_44888951752  393134357_20729844422_611159
#
#     process_step            date_time
# 783  confirm      2017-04-10 22:44:59
# 784  confirm      2017-04-10 22:44:58
# 785  confirm      2017-04-10 22:44:58
# 786  confirm      2017-04-10 22:44:12
# 787  step_3       2017-04-10 22:43:00
# 788  step_2       2017-04-10 22:42:51
# 789  step_3       2017-04-10 22:42:08
# 790  step_2       2017-04-10 22:40:45
# 791  step_1       2017-04-10 22:40:29
# 792  start        2017-04-10 22:40:02
# 860  step_1       2017-04-13 23:01:11
# 861  start        2017-04-13 23:01:09
# 862  start        2017-04-13 22:54:43

# %%
#Removing duplicates from "digital_footprints"

digital_footprints.drop_duplicates(inplace=True)

# %%
#Checking duplicates "digital_footprints"

digital_footprints.duplicated().sum()
# Out:
# 0

# %%
digital_footprints.nunique()
# Out:
# client_id       120157
# visitor_id      130236
# visit_id        158095
# process_step    5
# date_time       629363
# dtype: int64

# %%
#Checkind data types in "digital_footprints"

digital_footprints.dtypes
# Out:
# client_id       int64
# visitor_id      object
# visit_id        object
# process_step    object
# date_time       object
# dtype: object

# %%
#Changing datatype to datetime64 column "date_time" in "digital_footprints"

digital_footprints["date_time"] = pd.to_datetime(digital_footprints["date_time"])
digital_footprints.dtypes
# Out:
# client_id       int64
# visitor_id      object
# visit_id        object
# process_step    object
# date_time       datetime64[ns]
# dtype: object

# %% [markdown]
# # NEW Some efforts

# %%
# digital_footprints_new = digital_footprints \
# .groupby(["client_id", "visitor_id", "visit_id", "process_step"])["date_time"] \
# .min().reset_index()

# digital_footprints_new = digital_footprints_new.sort_values(["client_id", "visitor_id", "visit_id", 'date_time'], ascending=True)

# %%
#Merging dfs to add column variation (test or control)

digital_footprints = pd.merge(digital_footprints, experiment_roster, on='client_id', how='left')

digital_footprints.rename(columns={'Variation': 'variation'}, inplace=True)

digital_footprints.head(5)
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0  9988021    580560515_7732621733  781255054_21935453173_531117  step_3
# 1  9988021    580560515_7732621733  781255054_21935453173_531117  step_2
# 2  9988021    580560515_7732621733  781255054_21935453173_531117  step_3
# 3  9988021    580560515_7732621733  781255054_21935453173_531117  step_2
# 4  9988021    580560515_7732621733  781255054_21935453173_531117  step_3
#
#             date_time variation
# 0 2017-04-17 15:27:07  Test
# 1 2017-04-17 15:26:51  Test
# 2 2017-04-17 15:19:22  Test
# 3 2017-04-17 15:19:13  Test
# 4 2017-04-17 15:18:04  Test

# %%
digital_footprints_sorted = digital_footprints.sort_values(["client_id", "visitor_id", "visit_id", 'date_time'], ascending=True)
#IDEA: we can sort only by visit_id 

kpi_errors = digital_footprints_sorted.groupby(['client_id', 'visitor_id', 'visit_id'])['process_step'].apply(list).reset_index()
#IDEA: we can group only by visit_id

digital_footprints = pd.merge(digital_footprints_sorted, kpi_errors, on=['client_id', 'visitor_id', 'visit_id'] , how='left')
#IDEA: we can merge only by visit_id

digital_footprints
# Out:
#         client_id             visitor_id                      visit_id  \
# 0       169        201385055_71273495308  749567106_99161211863_557568
# 1       169        201385055_71273495308  749567106_99161211863_557568
# 2       169        201385055_71273495308  749567106_99161211863_557568
# 3       169        201385055_71273495308  749567106_99161211863_557568
# 4       169        201385055_71273495308  749567106_99161211863_557568
# ...     ...                          ...                           ...
# 744636  9999875    738878760_1556639849   931268933_219402947_599432
# 744637  9999875    738878760_1556639849   931268933_219402947_599432
# 744638  9999875    738878760_1556639849   931268933_219402947_599432
# 744639  9999875    738878760_1556639849   931268933_219402947_599432
# 744640  9999875    738878760_1556639849   931268933_219402947_599432
#
#        process_step_x           date_time variation  \
# 0       start         2017-04-12 20:19:36  NaN
# 1       step_1        2017-04-12 20:19:45  NaN
# 2       step_2        2017-04-12 20:20:31  NaN
# 3       step_3        2017-04-12 20:22:05  NaN
# 4       confirm       2017-04-12 20:23:09  NaN
# ...         ...                       ...  ...
# 744636  step_1        2017-06-01 22:40:08  NaN
# 744637  step_1        2017-06-01 22:41:28  NaN
# 744638  step_2        2017-06-01 22:41:47  NaN
# 744639  step_3        2017-06-01 22:44:58  NaN
# 744640  confirm       2017-06-01 22:48:39  NaN
#
#                                           process_step_y
# 0       [start, step_1, step_2, step_3, confirm]
# 1       [start, step_1, step_2, step_3, confirm]
# 2       [start, step_1, step_2, step_3, confirm]
# 3       [start, step_1, step_2, step_3, confirm]
# 4       [start, step_1, step_2, step_3, confirm]
# ...                                          ...
# 744636  [start, step_1, step_1, step_2, step_3, confirm]
# 744637  [start, step_1, step_1, step_2, step_3, confirm]
# 744638  [start, step_1, step_1, step_2, step_3, confirm]
# 744639  [start, step_1, step_1, step_2, step_3, confirm]
# 744640  [start, step_1, step_1, step_2, step_3, confirm]
#
# [744641 rows x 7 columns]

# %%
#For checking data

# digital_footprints.loc[digital_footprints['process_step_y'].apply(lambda x: x==['start', 'step_1', 'step_2', 'step_3', 'confirm'])]
# digital_footprints_check = digital_footprints.loc[digital_footprints_kpi['process_steps'].str.len() >= 5 ]
# digital_footprints_check = digital_footprints_check['process_steps'].value_counts().reset_index()

# %% [markdown]
# # < Time Spent on Each Step

# %%
#Adding new columns 'next_visit_id','next_date_time' for comparing next step and current step

lead_shifted_df = digital_footprints.shift(periods=-1)[['visit_id','date_time']].reset_index(drop=True)
digital_footprints_kpi_time = pd.merge(digital_footprints, lead_shifted_df, left_index=True, right_index=True)

# %%
digital_footprints_kpi_time.head(1)
# Out:
#    client_id             visitor_id                    visit_id_x  \
# 0  169        201385055_71273495308  749567106_99161211863_557568
#
#   process_step_x         date_time_x variation  \
# 0  start         2017-04-12 20:19:36  NaN
#
#                              process_step_y                    visit_id_y  \
# 0  [start, step_1, step_2, step_3, confirm]  749567106_99161211863_557568
#
#           date_time_y
# 0 2017-04-12 20:19:45

# %%
#Renaming column names 

digital_footprints_kpi_time = digital_footprints_kpi_time.rename(columns={'visit_id_x': 'visit_id', 
                                                  'process_step_x': 'process_step', 
                                                  'date_time_x': 'date_time',
                                                  'process_step_y': 'process_steps',
                                                  'visit_id_y': 'next_visit_id',
                                                  'date_time_y': 'next_date_time'
                                                 })

# %%
digital_footprints_kpi_time.head(1)
# Out:
#    client_id             visitor_id                      visit_id  \
# 0  169        201385055_71273495308  749567106_99161211863_557568
#
#   process_step           date_time variation  \
# 0  start       2017-04-12 20:19:36  NaN
#
#                               process_steps                 next_visit_id  \
# 0  [start, step_1, step_2, step_3, confirm]  749567106_99161211863_557568
#
#        next_date_time
# 0 2017-04-12 20:19:45

# %%
digital_footprints_kpi_time['step_time'] = digital_footprints_kpi_time.apply(
                                        lambda x: x['next_date_time'] - x['date_time'] 
                                            if x['process_step'] != 'confirm' 
                                                and x['next_visit_id'] == x['visit_id'] 
                                            else None, 
                                        axis=1
                                    )

# %%
digital_footprints_kpi_time.head(5)
# Out:
#    client_id             visitor_id                      visit_id  \
# 0  169        201385055_71273495308  749567106_99161211863_557568
# 1  169        201385055_71273495308  749567106_99161211863_557568
# 2  169        201385055_71273495308  749567106_99161211863_557568
# 3  169        201385055_71273495308  749567106_99161211863_557568
# 4  169        201385055_71273495308  749567106_99161211863_557568
#
#   process_step           date_time variation  \
# 0  start       2017-04-12 20:19:36  NaN
# 1  step_1      2017-04-12 20:19:45  NaN
# 2  step_2      2017-04-12 20:20:31  NaN
# 3  step_3      2017-04-12 20:22:05  NaN
# 4  confirm     2017-04-12 20:23:09  NaN
#
#                               process_steps                 next_visit_id  \
# 0  [start, step_1, step_2, step_3, confirm]  749567106_99161211863_557568
# 1  [start, step_1, step_2, step_3, confirm]  749567106_99161211863_557568
# 2  [start, step_1, step_2, step_3, confirm]  749567106_99161211863_557568
# 3  [start, step_1, step_2, step_3, confirm]  749567106_99161211863_557568
# 4  [start, step_1, step_2, step_3, confirm]  649044751_80905125055_554468
#
#        next_date_time       step_time
# 0 2017-04-12 20:19:45 0 days 00:00:09
# 1 2017-04-12 20:20:31 0 days 00:00:46
# 2 2017-04-12 20:22:05 0 days 00:01:34
# 3 2017-04-12 20:23:09 0 days 00:01:04
# 4 2017-06-01 07:26:55 NaT

# %%
#For checking errors

digital_footprints_kpi_time.sort_values('step_time', ascending = False)
digital_footprints_kpi_time.loc[digital_footprints_kpi_time['visit_id'] == '831987489_84761163210_335684']
# Out:
#         client_id            visitor_id                      visit_id  \
# 160840  2182225    390325070_4092351822  831987489_84761163210_335684
# 160841  2182225    390325070_4092351822  831987489_84761163210_335684
# 160842  2182225    390325070_4092351822  831987489_84761163210_335684
# 160843  2182225    390325070_4092351822  831987489_84761163210_335684
# 160844  2182225    390325070_4092351822  831987489_84761163210_335684
# 160845  2182225    390325070_4092351822  831987489_84761163210_335684
# 160846  2182225    390325070_4092351822  831987489_84761163210_335684
# 160847  2182225    390325070_4092351822  831987489_84761163210_335684
# 160848  2182225    390325070_4092351822  831987489_84761163210_335684
#
#        process_step           date_time variation  \
# 160840  start       2017-04-09 23:34:50  Control
# 160841  start       2017-04-09 23:39:53  Control
# 160842  start       2017-04-09 23:40:15  Control
# 160843  start       2017-04-09 23:40:23  Control
# 160844  start       2017-04-10 10:50:58  Control
# 160845  start       2017-04-10 10:51:14  Control
# 160846  start       2017-04-10 11:14:00  Control
# 160847  step_1      2017-04-10 11:14:07  Control
# 160848  step_2      2017-04-10 11:14:15  Control
#
#                                                             process_steps  \
# 160840  [start, start, start, start, start, start, start, step_1, step_2]
# 160841  [start, start, start, start, start, start, start, step_1, step_2]
# 160842  [start, start, start, start, start, start, start, step_1, step_2]
# 160843  [start, start, start, start, start, start, start, step_1, step_2]
# 160844  [start, start, start, start, start, start, start, step_1, step_2]
# 160845  [start, start, start, start, start, start, start, step_1, step_2]
# 160846  [start, start, start, start, start, start, start, step_1, step_2]
# 160847  [start, start, start, start, start, start, start, step_1, step_2]
# 160848  [start, start, start, start, start, start, start, step_1, step_2]
#
#                        next_visit_id      next_date_time       step_time
# 160840  831987489_84761163210_335684 2017-04-09 23:39:53 0 days 00:05:03
# 160841  831987489_84761163210_335684 2017-04-09 23:40:15 0 days 00:00:22
# 160842  831987489_84761163210_335684 2017-04-09 23:40:23 0 days 00:00:08
# 160843  831987489_84761163210_335684 2017-04-10 10:50:58 0 days 11:10:35
# 160844  831987489_84761163210_335684 2017-04-10 10:51:14 0 days 00:00:16
# 160845  831987489_84761163210_335684 2017-04-10 11:14:00 0 days 00:22:46
# 160846  831987489_84761163210_335684 2017-04-10 11:14:07 0 days 00:00:07
# 160847  831987489_84761163210_335684 2017-04-10 11:14:15 0 days 00:00:08
# 160848  334642200_87091138419_2689   2017-03-29 12:48:02 NaT

# %%
digital_footprints_kpi_time.groupby('process_step')['step_time'].mean()
# Out:
# process_step
# confirm   NaT
# start     0 days 00:01:01.339738435
# step_1    0 days 00:01:00.538742592
# step_2    0 days 00:01:32.629190357
# step_3    0 days 00:02:12.814548415
# Name: step_time, dtype: timedelta64[ns]

# %%
digital_footprints_kpi_time.dtypes
# Out:
# client_id         int64
# visitor_id        object
# visit_id          object
# process_step      object
# date_time         datetime64[ns]
# variation         object
# process_steps     object
# next_visit_id     object
# next_date_time    datetime64[ns]
# step_time         timedelta64[ns]
# dtype: object

# %% [markdown]
# ## Testing Hypotheses

# %%
#H0: mu test = control
#H1: mu test != control

# %%
#Convert "step_time" to hours, minutes, seconds

digital_footprints_kpi_time['hours'] = digital_footprints_kpi_time['step_time'].dt.components['hours']
digital_footprints_kpi_time['hours'].fillna(0, inplace = True)
digital_footprints_kpi_time['hours'] = digital_footprints_kpi_time['hours'].astype(int)

digital_footprints_kpi_time['minutes'] = digital_footprints_kpi_time['step_time'].dt.components['minutes']
digital_footprints_kpi_time['minutes'].fillna(0, inplace = True)
digital_footprints_kpi_time['minutes'] = digital_footprints_kpi_time['minutes'].astype(int)

digital_footprints_kpi_time['seconds'] = digital_footprints_kpi_time['step_time'].dt.components['seconds']
digital_footprints_kpi_time['seconds'].fillna(0, inplace = True)
digital_footprints_kpi_time['seconds'] = digital_footprints_kpi_time['seconds'].astype(int)

# %%
digital_footprints_kpi_time['time_total_seconds'] = digital_footprints_kpi_time['hours']*3600 + \
                                                    digital_footprints_kpi_time['minutes'] *60 + \
                                                    digital_footprints_kpi_time['seconds']

# %%
digital_footprints_kpi_time
# Out:
#         client_id             visitor_id                      visit_id  \
# 0       169        201385055_71273495308  749567106_99161211863_557568
# 1       169        201385055_71273495308  749567106_99161211863_557568
# 2       169        201385055_71273495308  749567106_99161211863_557568
# 3       169        201385055_71273495308  749567106_99161211863_557568
# 4       169        201385055_71273495308  749567106_99161211863_557568
# ...     ...                          ...                           ...
# 744636  9999875    738878760_1556639849   931268933_219402947_599432
# 744637  9999875    738878760_1556639849   931268933_219402947_599432
# 744638  9999875    738878760_1556639849   931268933_219402947_599432
# 744639  9999875    738878760_1556639849   931268933_219402947_599432
# 744640  9999875    738878760_1556639849   931268933_219402947_599432
#
#        process_step           date_time variation  \
# 0       start       2017-04-12 20:19:36  NaN
# 1       step_1      2017-04-12 20:19:45  NaN
# 2       step_2      2017-04-12 20:20:31  NaN
# 3       step_3      2017-04-12 20:22:05  NaN
# 4       confirm     2017-04-12 20:23:09  NaN
# ...         ...                     ...  ...
# 744636  step_1      2017-06-01 22:40:08  NaN
# 744637  step_1      2017-06-01 22:41:28  NaN
# 744638  step_2      2017-06-01 22:41:47  NaN
# 744639  step_3      2017-06-01 22:44:58  NaN
# 744640  confirm     2017-06-01 22:48:39  NaN
#
#                                            process_steps  \
# 0       [start, step_1, step_2, step_3, confirm]
# 1       [start, step_1, step_2, step_3, confirm]
# 2       [start, step_1, step_2, step_3, confirm]
# 3       [start, step_1, step_2, step_3, confirm]
# 4       [start, step_1, step_2, step_3, confirm]
# ...                                          ...
# 744636  [start, step_1, step_1, step_2, step_3, confirm]
# 744637  [start, step_1, step_1, step_2, step_3, confirm]
# 744638  [start, step_1, step_1, step_2, step_3, confirm]
# 744639  [start, step_1, step_1, step_2, step_3, confirm]
# 744640  [start, step_1, step_1, step_2, step_3, confirm]
#
#                        next_visit_id      next_date_time       step_time  \
# 0       749567106_99161211863_557568 2017-04-12 20:19:45 0 days 00:00:09
# 1       749567106_99161211863_557568 2017-04-12 20:20:31 0 days 00:00:46
# 2       749567106_99161211863_557568 2017-04-12 20:22:05 0 days 00:01:34
# 3       749567106_99161211863_557568 2017-04-12 20:23:09 0 days 00:01:04
# 4       649044751_80905125055_554468 2017-06-01 07:26:55 NaT
# ...                              ...                 ...  ..
# 744636  931268933_219402947_599432   2017-06-01 22:41:28 0 days 00:01:20
# 744637  931268933_219402947_599432   2017-06-01 22:41:47 0 days 00:00:19
# 744638  931268933_219402947_599432   2017-06-01 22:44:58 0 days 00:03:11
# 744639  931268933_219402947_599432   2017-06-01 22:48:39 0 days 00:03:41
# 744640  None                         NaT                 NaT
#
#         hours  minutes  seconds  time_total_seconds
# 0       0      0        9        9
# 1       0      0        46       46
# 2       0      1        34       94
# 3       0      1        4        64
# 4       0      0        0        0
# ...    ..     ..       ..       ..
# 744636  0      1        20       80
# 744637  0      0        19       19
# 744638  0      3        11       191
# 744639  0      3        41       221
# 744640  0      0        0        0
#
# [744641 rows x 14 columns]

# %%
df_test = digital_footprints_kpi_time[digital_footprints_kpi_time["variation"]=="Test"][["process_step", 'time_total_seconds']]
test = df_test.pivot(columns='process_step', values='time_total_seconds')
test.fillna(0, inplace = True)
test.drop('confirm', axis=1, inplace = True)
test = test.rename(columns={'start': 'start_to_step_1', 'step_1': 'step_1_to_step_2', 'step_2': 'step_2_to_step_3', 'step_3': 'step_3_to_confirm'})
test
test
# Out:
# process_step  start_to_step_1  step_1_to_step_2  step_2_to_step_3  \
# 12            7.0              0.0               0.0
# 13            0.0              32.0              0.0
# 14            0.0              0.0               99.0
# 15            0.0              0.0               0.0
# 16            0.0              0.0               0.0
# ...           ...              ...               ...
# 744612        0.0              287.0             0.0
# 744613        0.0              0.0               81.0
# 744614        0.0              0.0               0.0
# 744627        8.0              0.0               0.0
# 744628        0.0              0.0               0.0
#
# process_step  step_3_to_confirm
# 12            0.0
# 13            0.0
# 14            0.0
# 15            20.0
# 16            0.0
# ...           ...
# 744612        0.0
# 744613        0.0
# 744614        0.0
# 744627        0.0
# 744628        0.0
#
# [176699 rows x 4 columns]

# %%
digital_footprints_kpi_time.loc[digital_footprints_kpi_time['variation'] == 'Test']
# Out:
#         client_id             visitor_id                      visit_id  \
# 12      555        402506806_56087378777  637149525_38041617439_716659
# 13      555        402506806_56087378777  637149525_38041617439_716659
# 14      555        402506806_56087378777  637149525_38041617439_716659
# 15      555        402506806_56087378777  637149525_38041617439_716659
# 16      555        402506806_56087378777  637149525_38041617439_716659
# ...     ...                          ...                           ...
# 744612  9999729    843385170_36953471821  493310979_9209676464_421146
# 744613  9999729    843385170_36953471821  493310979_9209676464_421146
# 744614  9999729    843385170_36953471821  493310979_9209676464_421146
# 744627  9999832    145538019_54444341400  472154369_16714624241_585315
# 744628  9999832    145538019_54444341400  472154369_16714624241_585315
#
#        process_step           date_time variation  \
# 12      start       2017-04-15 12:57:56  Test
# 13      step_1      2017-04-15 12:58:03  Test
# 14      step_2      2017-04-15 12:58:35  Test
# 15      step_3      2017-04-15 13:00:14  Test
# 16      confirm     2017-04-15 13:00:34  Test
# ...         ...                     ...   ...
# 744612  step_1      2017-04-20 14:22:49  Test
# 744613  step_2      2017-04-20 14:27:36  Test
# 744614  start       2017-04-20 14:28:57  Test
# 744627  start       2017-05-16 16:46:03  Test
# 744628  step_1      2017-05-16 16:46:11  Test
#
#                                    process_steps  \
# 12      [start, step_1, step_2, step_3, confirm]
# 13      [start, step_1, step_2, step_3, confirm]
# 14      [start, step_1, step_2, step_3, confirm]
# 15      [start, step_1, step_2, step_3, confirm]
# 16      [start, step_1, step_2, step_3, confirm]
# ...                                          ...
# 744612  [start, step_1, step_2, start]
# 744613  [start, step_1, step_2, start]
# 744614  [start, step_1, step_2, start]
# 744627  [start, step_1]
# 744628  [start, step_1]
#
#                        next_visit_id      next_date_time       step_time  \
# 12      637149525_38041617439_716659 2017-04-15 12:58:03 0 days 00:00:07
# 13      637149525_38041617439_716659 2017-04-15 12:58:35 0 days 00:00:32
# 14      637149525_38041617439_716659 2017-04-15 13:00:14 0 days 00:01:39
# 15      637149525_38041617439_716659 2017-04-15 13:00:34 0 days 00:00:20
# 16      40369564_40101682850_311847  2017-04-12 15:41:28 NaT
# ...                             ...                  ...  ..
# 744612  493310979_9209676464_421146  2017-04-20 14:27:36 0 days 00:04:47
# 744613  493310979_9209676464_421146  2017-04-20 14:28:57 0 days 00:01:21
# 744614  85676722_11636430786_122704  2017-06-03 18:05:10 NaT
# 744627  472154369_16714624241_585315 2017-05-16 16:46:11 0 days 00:00:08
# 744628  715530422_68620416793_515645 2017-03-29 12:08:55 NaT
#
#         hours  minutes  seconds  time_total_seconds
# 12      0      0        7        7
# 13      0      0        32       32
# 14      0      1        39       99
# 15      0      0        20       20
# 16      0      0        0        0
# ...    ..     ..       ..       ..
# 744612  0      4        47       287
# 744613  0      1        21       81
# 744614  0      0        0        0
# 744627  0      0        8        8
# 744628  0      0        0        0
#
# [176699 rows x 14 columns]

# %%
df_control = digital_footprints_kpi_time[digital_footprints_kpi_time["variation"]=="Control"][["process_step", 'time_total_seconds']]
control = df_control.pivot(columns='process_step', values='time_total_seconds')
control.fillna(0, inplace = True)
control.drop('confirm', axis=1, inplace = True)
control = control.rename(columns={'start': 'start_to_step_1', 'step_1': 'step_1_to_step_2', 'step_2': 'step_2_to_step_3', 'step_3': 'step_3_to_confirm'})
control
# Out:
# process_step  start_to_step_1  step_1_to_step_2  step_2_to_step_3  \
# 57            49.0             0.0               0.0
# 58            0.0              63.0              0.0
# 59            0.0              9.0               0.0
# 60            0.0              0.0               275.0
# 61            0.0              0.0               0.0
# ...           ...              ...               ...
# 744508        0.0              0.0               14.0
# 744509        0.0              0.0               0.0
# 744510        0.0              0.0               0.0
# 744511        0.0              0.0               0.0
# 744562        0.0              0.0               0.0
#
# process_step  step_3_to_confirm
# 57            0.0
# 58            0.0
# 59            0.0
# 60            0.0
# 61            111.0
# ...             ...
# 744508        0.0
# 744509        423.0
# 744510        0.0
# 744511        0.0
# 744562        0.0
#
# [140536 rows x 4 columns]

# %%
result = st.ttest_ind(test, control, equal_var=False)
p_values = result[1]

# %%
alpha = 0.05
count = 0
for p_value in p_values:
    
    name_of_column = ['start_to_step_1', 'step_1_to_step_2', 'step_2_to_step_3', 'step_3_to_confirm']
   
    if p_value > alpha:
        print(f"{name_of_column[count]} time: We are not able to reject the null hypothesis")
    else:
        print(f"{name_of_column[count]} time: We reject the null hypothesis")
    count += 1
# Out:
# start_to_step_1 time: We are not able to reject the null hypothesis
# step_1_to_step_2 time: We reject the null hypothesis
# step_2_to_step_3 time: We reject the null hypothesis
# step_3_to_confirm time: We reject the null hypothesis

# %% [markdown]
# # Time Spent on Each Step >

# %% [markdown]
# ### Avg time per any step

# %%
#Copying df

digital_footprints_kpi = digital_footprints_kpi_time.copy(deep=True)

# %%
#To check unique values in evere column 

digital_footprints_kpi['process_steps'] = digital_footprints_kpi['process_steps'].apply(tuple)
digital_footprints_kpi.nunique()
# Out:
# client_id             120157
# visitor_id            130236
# visit_id              158095
# process_step          5
# date_time             629363
# variation             2
# process_steps         7043
# next_visit_id         158095
# next_date_time        629362
# step_time             2214
# hours                 7
# minutes               60
# seconds               60
# time_total_seconds    2214
# dtype: int64

# %%
digital_footprints_kpi['process_steps'].value_counts()
# Out:
# process_steps
# (start, step_1, step_2, step_3, confirm)                   235940
# (start, step_1, start, step_1, step_2, step_3, confirm)    28889
# (start, start, step_1, step_2, step_3, confirm)            18462
# (start, step_1, step_2, step_3)                            18064
# (start,)                                                   16798
#                                                            ...
# (confirm, step_1, step_1)                                  3
# (start, confirm, confirm)                                  3
# (step_2, confirm)                                          2
# (step_2, step_2)                                           2
# (step_1, step_3)                                           2
# Name: count, Length: 7043, dtype: int64

# %%
#Create new df where process_step == 'start' to add new column "date_time_start"
digital_footprints_kpi_start_time = digital_footprints_kpi.loc[digital_footprints_kpi['process_step'] == 'start']

#Choosing min data for column start by visit_id
digital_footprints_kpi_start_time_column  = digital_footprints_kpi_start_time \
.groupby(["visit_id"])["date_time"] \
.min().reset_index()

digital_footprints_kpi_start_time_column = digital_footprints_kpi_start_time_column.sort_values(["visit_id", 'date_time'], ascending=True)


#adding new column date_time_y = date_time_start 
digital_footprints_kpi = pd.merge(digital_footprints_kpi, digital_footprints_kpi_start_time_column, on='visit_id', how='left')
digital_footprints_kpi.head(5)
# Out:
#    client_id             visitor_id                      visit_id  \
# 0  169        201385055_71273495308  749567106_99161211863_557568
# 1  169        201385055_71273495308  749567106_99161211863_557568
# 2  169        201385055_71273495308  749567106_99161211863_557568
# 3  169        201385055_71273495308  749567106_99161211863_557568
# 4  169        201385055_71273495308  749567106_99161211863_557568
#
#   process_step         date_time_x variation  \
# 0  start       2017-04-12 20:19:36  NaN
# 1  step_1      2017-04-12 20:19:45  NaN
# 2  step_2      2017-04-12 20:20:31  NaN
# 3  step_3      2017-04-12 20:22:05  NaN
# 4  confirm     2017-04-12 20:23:09  NaN
#
#                               process_steps                 next_visit_id  \
# 0  (start, step_1, step_2, step_3, confirm)  749567106_99161211863_557568
# 1  (start, step_1, step_2, step_3, confirm)  749567106_99161211863_557568
# 2  (start, step_1, step_2, step_3, confirm)  749567106_99161211863_557568
# 3  (start, step_1, step_2, step_3, confirm)  749567106_99161211863_557568
# 4  (start, step_1, step_2, step_3, confirm)  649044751_80905125055_554468
#
#        next_date_time       step_time  hours  minutes  seconds  \
# 0 2017-04-12 20:19:45 0 days 00:00:09  0      0        9
# 1 2017-04-12 20:20:31 0 days 00:00:46  0      0        46
# 2 2017-04-12 20:22:05 0 days 00:01:34  0      1        34
# 3 2017-04-12 20:23:09 0 days 00:01:04  0      1        4
# 4 2017-06-01 07:26:55 NaT              0      0        0
#
#    time_total_seconds         date_time_y
# 0  9                  2017-04-12 20:19:36
# 1  46                 2017-04-12 20:19:36
# 2  94                 2017-04-12 20:19:36
# 3  64                 2017-04-12 20:19:36
# 4  0                  2017-04-12 20:19:36

# %%
digital_footprints_kpi.isna().sum()
# Out:
# client_id             0
# visitor_id            0
# visit_id              0
# process_step          0
# date_time_x           0
# variation             427406
# process_steps         0
# next_visit_id         1
# next_date_time        1
# step_time             172746
# hours                 0
# minutes               0
# seconds               0
# time_total_seconds    0
# date_time_y           22988
# dtype: int64

# %%
#Create new df where process_step == 'confirm' to add new column "date_time_confirm"
digital_footprints_kpi_cofirm_time = digital_footprints_kpi.loc[digital_footprints_kpi['process_step'] == 'confirm']

#Choosing min data for column cofirm by visit_id
digital_footprints_kpi_cofirm_column  = digital_footprints_kpi_cofirm_time \
.groupby(["visit_id"])["date_time_x"] \
.min().reset_index()
digital_footprints_kpi_cofirm_column = digital_footprints_kpi_cofirm_column.sort_values(["visit_id", 'date_time_x'], ascending=True)

#adding new column date_time_x_y = date_time_confirm
digital_footprints_kpi = pd.merge(digital_footprints_kpi, digital_footprints_kpi_cofirm_column, on='visit_id', how='left')
digital_footprints_kpi.head(5)
# Out:
#    client_id             visitor_id                      visit_id  \
# 0  169        201385055_71273495308  749567106_99161211863_557568
# 1  169        201385055_71273495308  749567106_99161211863_557568
# 2  169        201385055_71273495308  749567106_99161211863_557568
# 3  169        201385055_71273495308  749567106_99161211863_557568
# 4  169        201385055_71273495308  749567106_99161211863_557568
#
#   process_step       date_time_x_x variation  \
# 0  start       2017-04-12 20:19:36  NaN
# 1  step_1      2017-04-12 20:19:45  NaN
# 2  step_2      2017-04-12 20:20:31  NaN
# 3  step_3      2017-04-12 20:22:05  NaN
# 4  confirm     2017-04-12 20:23:09  NaN
#
#                               process_steps                 next_visit_id  \
# 0  (start, step_1, step_2, step_3, confirm)  749567106_99161211863_557568
# 1  (start, step_1, step_2, step_3, confirm)  749567106_99161211863_557568
# 2  (start, step_1, step_2, step_3, confirm)  749567106_99161211863_557568
# 3  (start, step_1, step_2, step_3, confirm)  749567106_99161211863_557568
# 4  (start, step_1, step_2, step_3, confirm)  649044751_80905125055_554468
#
#        next_date_time       step_time  hours  minutes  seconds  \
# 0 2017-04-12 20:19:45 0 days 00:00:09  0      0        9
# 1 2017-04-12 20:20:31 0 days 00:00:46  0      0        46
# 2 2017-04-12 20:22:05 0 days 00:01:34  0      1        34
# 3 2017-04-12 20:23:09 0 days 00:01:04  0      1        4
# 4 2017-06-01 07:26:55 NaT              0      0        0
#
#    time_total_seconds         date_time_y       date_time_x_y
# 0  9                  2017-04-12 20:19:36 2017-04-12 20:23:09
# 1  46                 2017-04-12 20:19:36 2017-04-12 20:23:09
# 2  94                 2017-04-12 20:19:36 2017-04-12 20:23:09
# 3  64                 2017-04-12 20:19:36 2017-04-12 20:23:09
# 4  0                  2017-04-12 20:19:36 2017-04-12 20:23:09

# %%
#Deleting duplicates by visit_id to have only unique values

digital_footprints_kpi.drop_duplicates(subset=['visit_id'], inplace=True)
digital_footprints_kpi.head(5)
# Out:
#     client_id             visitor_id                      visit_id  \
# 0   169        201385055_71273495308  749567106_99161211863_557568
# 5   336        64757908_3400128256    649044751_80905125055_554468
# 7   546        475037402_89828530214  731811517_9330176838_94847
# 12  555        402506806_56087378777  637149525_38041617439_716659
# 17  647        66758770_53988066587   40369564_40101682850_311847
#
#    process_step       date_time_x_x variation  \
# 0   start       2017-04-12 20:19:36  NaN
# 5   start       2017-06-01 07:26:55  NaN
# 7   start       2017-06-17 10:03:29  NaN
# 12  start       2017-04-15 12:57:56  Test
# 17  start       2017-04-12 15:41:28  Test
#
#                                process_steps                 next_visit_id  \
# 0   (start, step_1, step_2, step_3, confirm)  749567106_99161211863_557568
# 5   (start, start)                            649044751_80905125055_554468
# 7   (start, step_1, step_2, step_3, confirm)  731811517_9330176838_94847
# 12  (start, step_1, step_2, step_3, confirm)  637149525_38041617439_716659
# 17  (start, step_1, step_2, step_3, confirm)  40369564_40101682850_311847
#
#         next_date_time       step_time  hours  minutes  seconds  \
# 0  2017-04-12 20:19:45 0 days 00:00:09  0      0        9
# 5  2017-06-01 07:42:43 0 days 00:15:48  0      15       48
# 7  2017-06-17 10:03:39 0 days 00:00:10  0      0        10
# 12 2017-04-15 12:58:03 0 days 00:00:07  0      0        7
# 17 2017-04-12 15:41:35 0 days 00:00:07  0      0        7
#
#     time_total_seconds         date_time_y       date_time_x_y
# 0   9                  2017-04-12 20:19:36 2017-04-12 20:23:09
# 5   948                2017-06-01 07:26:55 NaT
# 7   10                 2017-06-17 10:03:29 2017-06-17 10:05:42
# 12  7                  2017-04-15 12:57:56 2017-04-15 13:00:34
# 17  7                  2017-04-12 15:41:28 2017-04-12 15:47:45

# %%
digital_footprints_kpi.duplicated(subset=['client_id']).sum()
# Out:
# 38740

# %%
digital_footprints_kpi.nunique()
# Out:
# client_id             119355
# visitor_id            130236
# visit_id              158095
# process_step          5
# date_time_x_x         151710
# variation             2
# process_steps         7013
# next_visit_id         137243
# next_date_time        151121
# step_time             1311
# hours                 5
# minutes               57
# seconds               60
# time_total_seconds    1311
# date_time_y           139232
# date_time_x_y         87281
# dtype: int64

# %%
#Removing columns process_step and date_time_x_x

digital_footprints_kpi.drop(['process_step', 'date_time_x_x'], axis=1, inplace = True)

# %%
#Renaming column names

digital_footprints_kpi.rename(columns={ 
                                              'date_time_y': 'start_date_time', 
                                              'date_time_x_y': 'confirm_date_time'}, inplace=True)

# %%
digital_footprints_kpi.head(5)
# Out:
#     client_id             visitor_id                      visit_id variation  \
# 0   169        201385055_71273495308  749567106_99161211863_557568  NaN
# 5   336        64757908_3400128256    649044751_80905125055_554468  NaN
# 7   546        475037402_89828530214  731811517_9330176838_94847    NaN
# 12  555        402506806_56087378777  637149525_38041617439_716659  Test
# 17  647        66758770_53988066587   40369564_40101682850_311847   Test
#
#                                process_steps                 next_visit_id  \
# 0   (start, step_1, step_2, step_3, confirm)  749567106_99161211863_557568
# 5   (start, start)                            649044751_80905125055_554468
# 7   (start, step_1, step_2, step_3, confirm)  731811517_9330176838_94847
# 12  (start, step_1, step_2, step_3, confirm)  637149525_38041617439_716659
# 17  (start, step_1, step_2, step_3, confirm)  40369564_40101682850_311847
#
#         next_date_time       step_time  hours  minutes  seconds  \
# 0  2017-04-12 20:19:45 0 days 00:00:09  0      0        9
# 5  2017-06-01 07:42:43 0 days 00:15:48  0      15       48
# 7  2017-06-17 10:03:39 0 days 00:00:10  0      0        10
# 12 2017-04-15 12:58:03 0 days 00:00:07  0      0        7
# 17 2017-04-12 15:41:35 0 days 00:00:07  0      0        7
#
#     time_total_seconds     start_date_time   confirm_date_time
# 0   9                  2017-04-12 20:19:36 2017-04-12 20:23:09
# 5   948                2017-06-01 07:26:55 NaT
# 7   10                 2017-06-17 10:03:29 2017-06-17 10:05:42
# 12  7                  2017-04-15 12:57:56 2017-04-15 13:00:34
# 17  7                  2017-04-12 15:41:28 2017-04-12 15:47:45

# %%
digital_footprints_kpi.isna().sum()
# Out:
# client_id             0
# visitor_id            0
# visit_id              0
# variation             89071
# process_steps         0
# next_visit_id         0
# next_date_time        0
# step_time             27358
# hours                 0
# minutes               0
# seconds               0
# time_total_seconds    0
# start_date_time       13193
# confirm_date_time     68269
# dtype: int64

# %%
digital_footprints_kpi.nunique()
# Out:
# client_id             119355
# visitor_id            130236
# visit_id              158095
# variation             2
# process_steps         7013
# next_visit_id         137243
# next_date_time        151121
# step_time             1311
# hours                 5
# minutes               57
# seconds               60
# time_total_seconds    1311
# start_date_time       139232
# confirm_date_time     87281
# dtype: int64

# %%
digital_footprints_kpi.isna().sum()
# Out:
# client_id             0
# visitor_id            0
# visit_id              0
# variation             89071
# process_steps         0
# next_visit_id         0
# next_date_time        0
# step_time             27358
# hours                 0
# minutes               0
# seconds               0
# time_total_seconds    0
# start_date_time       13193
# confirm_date_time     68269
# dtype: int64

# %%
digital_footprints_kpi['all_steps_time'] = digital_footprints_kpi['confirm_date_time'] - digital_footprints_kpi['start_date_time']

digital_footprints_kpi.head(5)
# Out:
#     client_id             visitor_id                      visit_id variation  \
# 0   169        201385055_71273495308  749567106_99161211863_557568  NaN
# 5   336        64757908_3400128256    649044751_80905125055_554468  NaN
# 7   546        475037402_89828530214  731811517_9330176838_94847    NaN
# 12  555        402506806_56087378777  637149525_38041617439_716659  Test
# 17  647        66758770_53988066587   40369564_40101682850_311847   Test
#
#                                process_steps                 next_visit_id  \
# 0   (start, step_1, step_2, step_3, confirm)  749567106_99161211863_557568
# 5   (start, start)                            649044751_80905125055_554468
# 7   (start, step_1, step_2, step_3, confirm)  731811517_9330176838_94847
# 12  (start, step_1, step_2, step_3, confirm)  637149525_38041617439_716659
# 17  (start, step_1, step_2, step_3, confirm)  40369564_40101682850_311847
#
#         next_date_time       step_time  hours  minutes  seconds  \
# 0  2017-04-12 20:19:45 0 days 00:00:09  0      0        9
# 5  2017-06-01 07:42:43 0 days 00:15:48  0      15       48
# 7  2017-06-17 10:03:39 0 days 00:00:10  0      0        10
# 12 2017-04-15 12:58:03 0 days 00:00:07  0      0        7
# 17 2017-04-12 15:41:35 0 days 00:00:07  0      0        7
#
#     time_total_seconds     start_date_time   confirm_date_time  all_steps_time
# 0   9                  2017-04-12 20:19:36 2017-04-12 20:23:09 0 days 00:03:33
# 5   948                2017-06-01 07:26:55 NaT                 NaT
# 7   10                 2017-06-17 10:03:29 2017-06-17 10:05:42 0 days 00:02:13
# 12  7                  2017-04-15 12:57:56 2017-04-15 13:00:34 0 days 00:02:38
# 17  7                  2017-04-12 15:41:28 2017-04-12 15:47:45 0 days 00:06:17

# %% [markdown]
# # < Error Rates KPI

# %%
#Copying df

digital_footprints_kpi_errors = digital_footprints_kpi.copy(deep=True)

# %%
#Function for counting errors 

def check_errors(steps):
    steps_order = {
        "start": "step_1",
        "step_1": "step_2",
        "step_2": "step_3",
        "step_3": "confirm",
        "confirm": "",
    }
    
    # steps = digital_footprints_kpi_errors['process_steps']
    
    i_1 = 0
    i_2 = 1
    count_errors = 0
    for i in range(len(steps) - 1):
        if steps[i_2] != steps_order[steps[i_1]]:
            count_errors += 1
        i_1 += 1
        i_2 += 1
    
    if count_errors == 0 and len(steps) < 5:
        count_errors += 1

    return count_errors

# %%
#Adding new column 'count_errors' using function 

digital_footprints_kpi_errors['count_errors'] = digital_footprints_kpi_errors.apply(lambda row: check_errors(row['process_steps']), axis = 1)

# %%
digital_footprints_kpi_errors.head(5)
# Out:
#     client_id             visitor_id                      visit_id variation  \
# 0   169        201385055_71273495308  749567106_99161211863_557568  NaN
# 5   336        64757908_3400128256    649044751_80905125055_554468  NaN
# 7   546        475037402_89828530214  731811517_9330176838_94847    NaN
# 12  555        402506806_56087378777  637149525_38041617439_716659  Test
# 17  647        66758770_53988066587   40369564_40101682850_311847   Test
#
#                                process_steps                 next_visit_id  \
# 0   (start, step_1, step_2, step_3, confirm)  749567106_99161211863_557568
# 5   (start, start)                            649044751_80905125055_554468
# 7   (start, step_1, step_2, step_3, confirm)  731811517_9330176838_94847
# 12  (start, step_1, step_2, step_3, confirm)  637149525_38041617439_716659
# 17  (start, step_1, step_2, step_3, confirm)  40369564_40101682850_311847
#
#         next_date_time       step_time  hours  minutes  seconds  \
# 0  2017-04-12 20:19:45 0 days 00:00:09  0      0        9
# 5  2017-06-01 07:42:43 0 days 00:15:48  0      15       48
# 7  2017-06-17 10:03:39 0 days 00:00:10  0      0        10
# 12 2017-04-15 12:58:03 0 days 00:00:07  0      0        7
# 17 2017-04-12 15:41:35 0 days 00:00:07  0      0        7
#
#     time_total_seconds     start_date_time   confirm_date_time  \
# 0   9                  2017-04-12 20:19:36 2017-04-12 20:23:09
# 5   948                2017-06-01 07:26:55 NaT
# 7   10                 2017-06-17 10:03:29 2017-06-17 10:05:42
# 12  7                  2017-04-15 12:57:56 2017-04-15 13:00:34
# 17  7                  2017-04-12 15:41:28 2017-04-12 15:47:45
#
#     all_steps_time  count_errors
# 0  0 days 00:03:33  0
# 5  NaT              1
# 7  0 days 00:02:13  0
# 12 0 days 00:02:38  0
# 17 0 days 00:06:17  0

# %%
#Checking data

digital_footprints_kpi_errors[['process_steps', 'count_errors']].loc[digital_footprints_kpi_errors['count_errors'] >= 4]
# Out:
#                                                                                                                                                                                                                                                   process_steps  \
# 57      (start, step_1, step_1, step_2, step_3, step_1, step_1, step_2, step_1)
# 102     (start, step_1, start, step_1, step_2, step_3, start, start, start, step_3)
# 125     (start, step_1, step_2, step_3, confirm, confirm, confirm, confirm, confirm)
# 139     (start, step_1, step_2, step_1, step_2, start, start, start, start, step_2, step_1)
# 227     (start, start, start, start, step_1, step_2, step_3, step_2, step_3, confirm)
# ...                                                                               ...
# 744274  (start, step_1, step_2, step_3, step_3, step_2, step_1, step_2, step_2, step_3, step_2, step_1, step_2, step_3, step_2, step_1, step_1, step_2, step_3, step_2, step_1, step_2, step_3, step_2, step_1, start, step_1, step_2, step_3, step_3, confirm)
# 744321  (start, start, start, start, step_1, step_2, step_3, start)
# 744462  (start, start, start, step_1, start, step_1, start, step_1, step_2, step_3, start, step_1, step_2, step_3, confirm)
# 744501  (start, step_1, step_2, step_2, step_2, step_3, step_1, step_2, step_3, step_3, confirm)
# 744615  (start, step_1, step_2, step_3, step_2, step_1, start, start, step_1, step_2, step_3, confirm)
#
#         count_errors
# 57      4
# 102     5
# 125     4
# 139     7
# 227     4
# ...    ..
# 744274  15
# 744321  4
# 744462  5
# 744501  4
# 744615  4
#
# [9592 rows x 2 columns]

# %%
#Adding new column 'count_steps' to count number of all steps

digital_footprints_kpi_errors['count_steps'] = digital_footprints_kpi_errors['process_steps'].str.len()

# %%
#Defining new column 'error_rates_kpi'

digital_footprints_kpi_errors['error_rates_kpi'] = digital_footprints_kpi_errors['count_errors']/digital_footprints_kpi_errors['count_steps']
digital_footprints_kpi_errors['error_rates_kpi'] = digital_footprints_kpi_errors['error_rates_kpi'].round(2)

# %%
digital_footprints_kpi_errors.head(5)
# Out:
#     client_id             visitor_id                      visit_id variation  \
# 0   169        201385055_71273495308  749567106_99161211863_557568  NaN
# 5   336        64757908_3400128256    649044751_80905125055_554468  NaN
# 7   546        475037402_89828530214  731811517_9330176838_94847    NaN
# 12  555        402506806_56087378777  637149525_38041617439_716659  Test
# 17  647        66758770_53988066587   40369564_40101682850_311847   Test
#
#                                process_steps                 next_visit_id  \
# 0   (start, step_1, step_2, step_3, confirm)  749567106_99161211863_557568
# 5   (start, start)                            649044751_80905125055_554468
# 7   (start, step_1, step_2, step_3, confirm)  731811517_9330176838_94847
# 12  (start, step_1, step_2, step_3, confirm)  637149525_38041617439_716659
# 17  (start, step_1, step_2, step_3, confirm)  40369564_40101682850_311847
#
#         next_date_time       step_time  hours  minutes  seconds  \
# 0  2017-04-12 20:19:45 0 days 00:00:09  0      0        9
# 5  2017-06-01 07:42:43 0 days 00:15:48  0      15       48
# 7  2017-06-17 10:03:39 0 days 00:00:10  0      0        10
# 12 2017-04-15 12:58:03 0 days 00:00:07  0      0        7
# 17 2017-04-12 15:41:35 0 days 00:00:07  0      0        7
#
#     time_total_seconds     start_date_time   confirm_date_time  \
# 0   9                  2017-04-12 20:19:36 2017-04-12 20:23:09
# 5   948                2017-06-01 07:26:55 NaT
# 7   10                 2017-06-17 10:03:29 2017-06-17 10:05:42
# 12  7                  2017-04-15 12:57:56 2017-04-15 13:00:34
# 17  7                  2017-04-12 15:41:28 2017-04-12 15:47:45
#
#     all_steps_time  count_errors  count_steps  error_rates_kpi
# 0  0 days 00:03:33  0             5            0.0
# 5  NaT              1             2            0.5
# 7  0 days 00:02:13  0             5            0.0
# 12 0 days 00:02:38  0             5            0.0
# 17 0 days 00:06:17  0             5            0.0

# %%
digital_footprints_kpi_errors['error_rates_kpi'].unique()
# Out:
# array([0.  , 0.5 , 0.22, 0.17, 0.4 , 0.14, 0.75, 0.44, 1.  , 0.33, 0.64,
#        0.29, 0.25, 0.2 , 0.3 , 0.67, 0.88, 0.43, 0.6 , 0.38, 0.57, 0.8 ,
#        0.65, 0.12, 0.47, 0.27, 0.69, 0.36, 0.62, 0.18, 0.11, 0.31, 0.58,
#        0.86, 0.83, 0.56, 0.89, 0.71, 0.52, 0.73, 0.55, 0.61, 0.42, 0.53,
#        0.91, 0.46, 0.54, 0.59, 0.7 , 0.23, 0.48, 0.9 , 0.93, 0.45, 0.35,
#        0.21, 0.79, 0.68, 0.78, 0.41, 0.1 , 0.39, 0.37, 0.94, 0.63, 0.77,
#        0.82, 0.32, 0.74, 0.15, 0.85, 0.72, 0.92, 0.66, 0.87, 0.24, 0.95,
#        0.26, 0.76, 0.51, 0.96, 0.28, 0.84, 0.81])

# %% [markdown]
# ### Testing Hypotheses

# %%
#H0: mu test = control
#H1: mu test != control

# %%
df_test_errors = digital_footprints_kpi_errors[digital_footprints_kpi_errors["variation"]=="Test"]["error_rates_kpi"]
df_control_errors = digital_footprints_kpi_errors[digital_footprints_kpi_errors["variation"]=="Control"]["error_rates_kpi"]

# %%
print(f'New version: {df_test_errors.mean()}')
print(f'Old version: {df_control_errors.mean()}')
# Out:
# New version: 0.35548878075155455
# Old version: 0.3667081850533808

# %%
result = st.ttest_ind(df_test_errors, df_control_errors, equal_var=False)

# %%
p_value = result[1]

# %%
alpha = 0.05

if p_value > alpha:
    print("We are not able to reject the null hypothesis")
else:
    print("We reject the null hypothesis")
# Out:
# We reject the null hypothesis

# %% [markdown]
# # Error Rates KPI >

# %% [markdown]
# # < Completion Rate

# %%
#Copying df

digital_footprints_kpis = digital_footprints_kpi_errors.copy(deep=True)

digital_footprints_kpis['completion_rate'] = digital_footprints_kpis.apply(lambda x: 
                                                                                       1 if 'confirm' in x['process_steps'] 
                                                                                       else 0, 
                                                                                       axis = 1
                                                                                      )
digital_footprints_kpis.head(5)
# Out:
#     client_id             visitor_id                      visit_id variation  \
# 0   169        201385055_71273495308  749567106_99161211863_557568  NaN
# 5   336        64757908_3400128256    649044751_80905125055_554468  NaN
# 7   546        475037402_89828530214  731811517_9330176838_94847    NaN
# 12  555        402506806_56087378777  637149525_38041617439_716659  Test
# 17  647        66758770_53988066587   40369564_40101682850_311847   Test
#
#                                process_steps                 next_visit_id  \
# 0   (start, step_1, step_2, step_3, confirm)  749567106_99161211863_557568
# 5   (start, start)                            649044751_80905125055_554468
# 7   (start, step_1, step_2, step_3, confirm)  731811517_9330176838_94847
# 12  (start, step_1, step_2, step_3, confirm)  637149525_38041617439_716659
# 17  (start, step_1, step_2, step_3, confirm)  40369564_40101682850_311847
#
#         next_date_time       step_time  hours  minutes  seconds  \
# 0  2017-04-12 20:19:45 0 days 00:00:09  0      0        9
# 5  2017-06-01 07:42:43 0 days 00:15:48  0      15       48
# 7  2017-06-17 10:03:39 0 days 00:00:10  0      0        10
# 12 2017-04-15 12:58:03 0 days 00:00:07  0      0        7
# 17 2017-04-12 15:41:35 0 days 00:00:07  0      0        7
#
#     time_total_seconds     start_date_time   confirm_date_time  \
# 0   9                  2017-04-12 20:19:36 2017-04-12 20:23:09
# 5   948                2017-06-01 07:26:55 NaT
# 7   10                 2017-06-17 10:03:29 2017-06-17 10:05:42
# 12  7                  2017-04-15 12:57:56 2017-04-15 13:00:34
# 17  7                  2017-04-12 15:41:28 2017-04-12 15:47:45
#
#     all_steps_time  count_errors  count_steps  error_rates_kpi  \
# 0  0 days 00:03:33  0             5            0.0
# 5  NaT              1             2            0.5
# 7  0 days 00:02:13  0             5            0.0
# 12 0 days 00:02:38  0             5            0.0
# 17 0 days 00:06:17  0             5            0.0
#
#     completion_rate
# 0   1
# 5   0
# 7   1
# 12  1
# 17  1

# %% [markdown]
# # Completion Rate >

# %% [markdown]
# # < Test other Hypothesis

# %% [markdown]
# ### You might want to test whether the average age of clients engaging with the new process is the same as those engaging with the old process.

# %%
#H0: mu test = control
#H1: mu test != control

# %%
df_test_age = client_profiles[client_profiles["Variation"]=="Test"]["clnt_age"]
df_control_age = client_profiles[client_profiles["Variation"]=="Control"]["clnt_age"]

# %%
print(f'New version: {df_test_age.mean()}')
print(f'Old version: {df_control_age.mean()}')
# Out:
# New version: 47.16392196135158
# Old version: 47.49889488672589

# %%
result = st.ttest_ind(df_test_age, df_control_age , equal_var=True)
p_value = result[1]
p_value
# Out:
# 0.015542695270791742

# %%
alpha = 0.05

if p_value > alpha:
    print("We are not able to reject the null hypothesis")
else:
    print("We reject the null hypothesis")
# Out:
# We reject the null hypothesis

# %%
#Used for checking

#In order to calculate test statistic we need

#sample mean
mean = df_test_age.mean()

#standard deviation of sample
s = df_test_age.std(ddof=1)

#sample size
n = len(df_test_age)

#hypothesized population mean
mu = df_control_age.mean()

stat = (mean - mu)/(s/np.sqrt(n))
print(f'stat: {stat}')

p_value = st.t.sf(abs(stat), n-1)*2
print(f'p_value: {p_value}')
# Out:
# stat: -3.545202289773042
# p_value: 0.00039297617699876706

# %%
if p_value > alpha:
    print("We are not able to reject the null hypothesis")
else:
    print("We reject the null hypotesis")
# Out:
# We reject the null hypotesis

# %% [markdown]
# ### You might want to test if the average client tenure (how long they’ve been with Vanguard) of those engaging with the new process is the same as those engaging with the old process

# %%
#H0: mu test = control
#H1: mu test != control

# %%
df_test_tenure = client_profiles[client_profiles["Variation"]=="Test"]["clnt_tenure_mnth"]
df_control_tenure = client_profiles[client_profiles["Variation"]=="Control"]["clnt_tenure_mnth"]

# %%
print(f'New version: {df_test_tenure.mean()}')
print(f'Old version: {df_control_tenure.mean()}')
# Out:
# New version: 149.8528986313564
# Old version: 151.06018616908233

# %%
result = st.ttest_ind(df_test_tenure, df_control_tenure , equal_var=True)
p_value = result[1]
p_value
# Out:
# 0.09866198087311466

# %%
alpha = 0.05

if p_value > alpha:
    print("We are not able to reject the null hypothesis")
else:
    print("We reject the null hypothesis")
# Out:
# We are not able to reject the null hypothesis

# %% [markdown]
# # Testing other Hypothesis >
